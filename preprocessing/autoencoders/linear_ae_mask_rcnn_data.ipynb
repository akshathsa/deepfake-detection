# %% [markdown]
# # Linear Autoencoder with Mask R-CNN Data

# %%
import cv2
import json
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import shutil
import torch
from albumentations import Compose, PadIfNeeded
from torch import nn
from torch import optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms.functional import to_tensor

# %%
import sys
sys.path.append(os.path.join('..', '..', 'models', 'vit', 'efficient-vit', 'transforms'))
from albu import IsotropicResize

# %%
# Check CUDA
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if torch.cuda.is_available():
    print("CUDA is available!")
    print(f"Current device: {torch.cuda.get_device_name(device)}")
else:
    print("CUDA unavailable :(")
# Out:
# CUDA is available!
# Current device: NVIDIA GeForce RTX 3060 Ti

# %% [markdown]
# ## Data Pre-Processing

# %%
with open(os.path.join('..', '..', 'dfdc_train_part_45', 'metadata.json'), 'r', encoding='utf-8') as f:
    metadata = json.load(f)

display(metadata)
# Out:
# {'gthvvygfcj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lxeqbyddvt.mp4'},
#  'yunqitmhjo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hbrgvmrtnn.mp4'},
#  'mwizcjywkd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stdavraahk.mp4'},
#  'ymswdhnnyp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gwzttezkpv.mp4'},
#  'lsfsintfky.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xrtmepdfyh.mp4'},
#  'bfkfrtmiub.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'ryuocfdklj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'jrtgsrmvfu.mp4': {'label': 'REAL', 'split': 'train'},
#  'xuszvuvabr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lauifordgs.mp4'},
#  'tltyusajlj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'ipouzwmwit.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'icbzbcwlgf.mp4'},
#  'dbixwxtuxs.mp4': {'label': 'REAL', 'split': 'train'},
#  'aomsunroqu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'jqvedzkrxw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'cnlovaecgh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'jyfuodeqkv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'wrqvfxdyzu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rgxhztngwi.mp4'},
#  'zbzujyyzdz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tjyuudtkme.mp4'},
#  'pnqrgzrhmo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ymyjtjywus.mp4'},
#  'xtkehdbbca.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'pxwsxsqrxo.mp4': {'label': 'REAL', 'split': 'train'},
#  'ihszkmcwvw.mp4': {'label': 'REAL', 'split': 'train'},
#  'byhfdzwppd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'paorozwtbf.mp4'},
#  'aqpgiwkfuc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xrtmepdfyh.mp4'},
#  'uuilzsbtgz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'ruwwxklbpw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stwaypekwh.mp4'},
#  'kshkjrzams.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ybmpcnodrg.mp4'},
#  'vfkgzfdjsl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'lauifordgs.mp4': {'label': 'REAL', 'split': 'train'},
#  'ixvztrxchg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'jpkoxyoqos.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'dffkcrccsj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'vnskrqkpcg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sgdnbofecu.mp4'},
#  'gldzguwfao.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'tyxiuohdfk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'wxotxrfdef.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'fafelguets.mp4': {'label': 'REAL', 'split': 'train'},
#  'cualykjhoa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'awsceniain.mp4'},
#  'rwoywxdxra.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'xufyybetre.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'soellqnrep.mp4'},
#  'nfhclzgibh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ybmpcnodrg.mp4'},
#  'yczwfqgluz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'swxoosqtkl.mp4'},
#  'vjwpuuwfyy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjikbuyuri.mp4'},
#  'svyrunawef.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gwzttezkpv.mp4'},
#  'rnemedxvyr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'czlfmczgfs.mp4'},
#  'cmyvjmgldk.mp4': {'label': 'REAL', 'split': 'train'},
#  'qiczijfwzc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jrtgsrmvfu.mp4'},
#  'wvmrsucbsq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cmyvjmgldk.mp4'},
#  'cshhakbofs.mp4': {'label': 'REAL', 'split': 'train'},
#  'pladypzcgb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stdavraahk.mp4'},
#  'pdbvtgibqb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ymyjtjywus.mp4'},
#  'jnkiecpeve.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'iovjcaptmz.mp4': {'label': 'REAL', 'split': 'train'},
#  'xjwyksuopn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'yghxoihrle.mp4': {'label': 'REAL', 'split': 'train'},
#  'mtqxfiltpk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jlzelzmyin.mp4'},
#  'wxqsbaujah.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'soellqnrep.mp4'},
#  'sifohlniaz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ytowqhkwnk.mp4'},
#  'qcwnjxtwkx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'awsceniain.mp4'},
#  'czylfgmknr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'swxoosqtkl.mp4'},
#  'dbvvehcocv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'ynfssrepte.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jrtgsrmvfu.mp4'},
#  'pisxzqepkr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jrtgsrmvfu.mp4'},
#  'xwdspcjets.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'iyaxgpepqr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'vmasbhlvba.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ihszkmcwvw.mp4'},
#  'jvjstqodrq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ytowqhkwnk.mp4'},
#  'bbhjnxbdco.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'sbypubftlo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'muuwtyrtxs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'goolpwftkw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sgdnbofecu.mp4'},
#  'parwxygsid.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ocsqqqduxx.mp4'},
#  'piiicjgdvu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'nhohwyteco.mp4'},
#  'ovozllyabv.mp4': {'label': 'REAL', 'split': 'train'},
#  'ytowqhkwnk.mp4': {'label': 'REAL', 'split': 'train'},
#  'vhcnckkcmb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xrtmepdfyh.mp4'},
#  'ipwroeubye.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hbrgvmrtnn.mp4'},
#  'smcdunqkaw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ytowqhkwnk.mp4'},
#  'ikcpaaosur.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'hnwwmhenfg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdlhavfmit.mp4'},
#  'leekjavohd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'icbzbcwlgf.mp4'},
#  'oyhdirhgnv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lobucnofjd.mp4'},
#  'fgqmmehmev.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'emdoggnrga.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'iatevqworc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tjyuudtkme.mp4'},
#  'zbyrrujrch.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iovjcaptmz.mp4'},
#  'txfozivwlq.mp4': {'label': 'REAL', 'split': 'train'},
#  'mevliovheo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'gdygdvuyum.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'icbzbcwlgf.mp4'},
#  'wxzmsudejm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xrtmepdfyh.mp4'},
#  'uicmpptfdm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sgdnbofecu.mp4'},
#  'cjptajsjfh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'czquwucvls.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'jtkyoulizr.mp4': {'label': 'REAL', 'split': 'train'},
#  'apvktqqhcq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hbrgvmrtnn.mp4'},
#  'ogjiicvwia.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pbtbftzpia.mp4'},
#  'jbxiszwoms.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rgxhztngwi.mp4'},
#  'atfuphvjft.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'soellqnrep.mp4': {'label': 'REAL', 'split': 'train'},
#  'kxlprsoigl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'nhohwyteco.mp4'},
#  'heszotticv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'ufrizjdfqj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jlzelzmyin.mp4'},
#  'npntekdlue.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'soellqnrep.mp4'},
#  'jglhlccrhl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stwaypekwh.mp4'},
#  'chombbeegs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdlhavfmit.mp4'},
#  'pbtbftzpia.mp4': {'label': 'REAL', 'split': 'train'},
#  'teblnhhyir.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'lxeqbyddvt.mp4': {'label': 'REAL', 'split': 'train'},
#  'tvprrlprkh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stdavraahk.mp4'},
#  'vtlbiwkann.mp4': {'label': 'REAL', 'split': 'train'},
#  'qzhmbvmqtc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tjyuudtkme.mp4'},
#  'fqepjykfru.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qiklmoeita.mp4'},
#  'qxvzphuqgg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'qgylpvnvfo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'xanyqzjdsw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jrtgsrmvfu.mp4'},
#  'oaubuajywo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'swxoosqtkl.mp4': {'label': 'REAL', 'split': 'train'},
#  'bglklkiayu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'dbixwxtuxs.mp4'},
#  'fpobacwdrp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'yoijfacueg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjikbuyuri.mp4'},
#  'ocsqqqduxx.mp4': {'label': 'REAL', 'split': 'train'},
#  'prruktoyam.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pjqqnbiiwv.mp4'},
#  'apcjdaqzwa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yghxoihrle.mp4'},
#  'qgjsymcviq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'oajykosmjr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wauoeybril.mp4'},
#  'bmpgdxzwpt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'cyjcfkdjgp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'rfhwnzuihr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jlzelzmyin.mp4'},
#  'cerwxjqsmv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'azaahiwadu.mp4'},
#  'cplkdbfpxj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lobucnofjd.mp4'},
#  'wmavhagafr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pxwsxsqrxo.mp4'},
#  'djvbsnsiah.mp4': {'label': 'REAL', 'split': 'train'},
#  'amdsocyvfq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xeyzkwymwu.mp4'},
#  'vqrsnqwezt.mp4': {'label': 'REAL', 'split': 'train'},
#  'peiyocyctt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'sjikbuyuri.mp4': {'label': 'REAL', 'split': 'train'},
#  'ugzonpnovr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdlhavfmit.mp4'},
#  'wdafpwgevq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdnepyqjiy.mp4'},
#  'buxmjdnowq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'vhorpvvjow.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'swxoosqtkl.mp4'},
#  'epktjbgnju.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gztffgsxpt.mp4'},
#  'eqbscfnyaa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rgxhztngwi.mp4'},
#  'ddieekaouu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jlzelzmyin.mp4'},
#  'kujjwjaewk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gztffgsxpt.mp4'},
#  'kkautgqcwq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lauifordgs.mp4'},
#  'byavookkdu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lauifordgs.mp4'},
#  'paorozwtbf.mp4': {'label': 'REAL', 'split': 'train'},
#  'wauoeybril.mp4': {'label': 'REAL', 'split': 'train'},
#  'wfoubyslvu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'nhohwyteco.mp4'},
#  'lldgblyhak.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'gwzttezkpv.mp4': {'label': 'REAL', 'split': 'train'},
#  'bwtgujxyhs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'ddfrexfnhg.mp4': {'label': 'REAL', 'split': 'train'},
#  'lojugsogpt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'fbxycbrpnd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'lthqfvpfjj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'kinekbuzkx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lobucnofjd.mp4'},
#  'ccevbixrwu.mp4': {'label': 'REAL', 'split': 'train'},
#  'sbsqzwjwog.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'qzdirjlxbw.mp4': {'label': 'REAL', 'split': 'train'},
#  'vprrnxtryn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cojfnbtfkr.mp4'},
#  'smwpthfdcd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'hvtsyiuvcn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ocsqqqduxx.mp4'},
#  'kevdysuura.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'txfozivwlq.mp4'},
#  'kdhfvtnpik.mp4': {'label': 'REAL', 'split': 'train'},
#  'baphsbkpbz.mp4': {'label': 'REAL', 'split': 'train'},
#  'snwvzbrgvg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'ttetdytpgh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'vhykpqniml.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qiklmoeita.mp4'},
#  'ayoyqfyvxb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'txfozivwlq.mp4'},
#  'cvbjxpwoie.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vqrsnqwezt.mp4'},
#  'hnmefdzxxf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'pmtgzafbsg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vqrsnqwezt.mp4'},
#  'lrxsznrmgy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'stwaypekwh.mp4': {'label': 'REAL', 'split': 'train'},
#  'mazmrfplfz.mp4': {'label': 'REAL', 'split': 'train'},
#  'pwvidqwogv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iovjcaptmz.mp4'},
#  'twidckwatq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rgxhztngwi.mp4'},
#  'gfsxrnrsmh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ocsqqqduxx.mp4'},
#  'obmfjpwhgs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'bctwtzhnje.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sgdnbofecu.mp4'},
#  'tswmtnhfmn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vtlbiwkann.mp4'},
#  'odmyurcpoj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pxwsxsqrxo.mp4'},
#  'xmphbtlrck.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'uvgjewintf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'fvdhqemlxe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kffwdagndv.mp4'},
#  'vkqmzqfrok.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ytowqhkwnk.mp4'},
#  'fzczxqogem.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gztffgsxpt.mp4'},
#  'agkvcuntqw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stdavraahk.mp4'},
#  'tzybvmvyyd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'pylwstofpv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'icbzbcwlgf.mp4': {'label': 'REAL', 'split': 'train'},
#  'yoorhdcrqk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yghxoihrle.mp4'},
#  'nhohwyteco.mp4': {'label': 'REAL', 'split': 'train'},
#  'dphqaflxdo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'vpbsqpnolc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cmyvjmgldk.mp4'},
#  'kzwmxhplnd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'txfozivwlq.mp4'},
#  'jvmjjaljep.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sytddqezij.mp4'},
#  'anxeqgmacn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'uerapqglmr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'byzhqvspaz.mp4'},
#  'npiptahdld.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'hxrruqinnh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'vrtymxriej.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdnepyqjiy.mp4'},
#  'pvbdhnfemx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cojfnbtfkr.mp4'},
#  'lkyjryanyz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'tvffpggbrc.mp4': {'label': 'REAL', 'split': 'train'},
#  'rgxhztngwi.mp4': {'label': 'REAL', 'split': 'train'},
#  'zahxyscmlj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'ncnubwzwhf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ihszkmcwvw.mp4'},
#  'stdavraahk.mp4': {'label': 'REAL', 'split': 'train'},
#  'ivbyvtqgzd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'baphsbkpbz.mp4'},
#  'isdklqbdnf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ybmpcnodrg.mp4'},
#  'arrflbwjau.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'nxanysfxgs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stdavraahk.mp4'},
#  'vmirklkeyi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'soellqnrep.mp4'},
#  'hfflsxqsqi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yghxoihrle.mp4'},
#  'lyrkhmyebn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hbrgvmrtnn.mp4'},
#  'adxkyxkepg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wauoeybril.mp4'},
#  'nhnqzsreme.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'tzkglkvofq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'kjjdbwrars.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'czlfmczgfs.mp4'},
#  'cojfnbtfkr.mp4': {'label': 'REAL', 'split': 'train'},
#  'sioagbbntu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'dbixwxtuxs.mp4'},
#  'lilanxqzsm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pbtbftzpia.mp4'},
#  'azwusfxjmb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'rmgmravhdx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lxeqbyddvt.mp4'},
#  'bpkpvrqduq.mp4': {'label': 'REAL', 'split': 'train'},
#  'hfcezskxnq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xeyzkwymwu.mp4'},
#  'tmqiddrjil.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdlhavfmit.mp4'},
#  'qgqdlhcpli.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'nkwjnyzyjm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'prqmuxhuxz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gztffgsxpt.mp4'},
#  'ogoqbsdgjp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ddfrexfnhg.mp4'},
#  'dtqhijoxgk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'akddowubef.mp4'},
#  'peudsjqzjk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ddfrexfnhg.mp4'},
#  'ayvrrldwmy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ihszkmcwvw.mp4'},
#  'wvatstfqdp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'sobgfhhcam.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ymyjtjywus.mp4'},
#  'hbrgvmrtnn.mp4': {'label': 'REAL', 'split': 'train'},
#  'kqekclcmnd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'vhqgeyngzg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ufizpokygp.mp4'},
#  'cnbtegsjlx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cmyvjmgldk.mp4'},
#  'htrwxzllri.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'vphynfhigk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'seellwbtdq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'baphsbkpbz.mp4'},
#  'vgpjbehlzv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tjyuudtkme.mp4'},
#  'enhqfydjvr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'ruqedmfwoh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sytddqezij.mp4'},
#  'hizygxelaj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jbcnsmlysc.mp4'},
#  'fgrxdtkqod.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'dhetuxjmnz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qiklmoeita.mp4'},
#  'smlkevdmyi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lauifordgs.mp4'},
#  'bbuyagtrip.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tjyuudtkme.mp4'},
#  'gobvfbczxj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ufizpokygp.mp4'},
#  'sytddqezij.mp4': {'label': 'REAL', 'split': 'train'},
#  'zdlhavfmit.mp4': {'label': 'REAL', 'split': 'train'},
#  'wbyfiwfrgf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'mpzrpapqra.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iovjcaptmz.mp4'},
#  'akddowubef.mp4': {'label': 'REAL', 'split': 'train'},
#  'kvdnzpwaen.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'baphsbkpbz.mp4'},
#  'edpjgsunfy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'awsceniain.mp4'},
#  'kffwdagndv.mp4': {'label': 'REAL', 'split': 'train'},
#  'rupmycdwnn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'azaahiwadu.mp4'},
#  'xeyzkwymwu.mp4': {'label': 'REAL', 'split': 'train'},
#  'fvvzvoommr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pxwsxsqrxo.mp4'},
#  'awsceniain.mp4': {'label': 'REAL', 'split': 'train'},
#  'gvcwrbcqdd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'gnytcpethj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ihszkmcwvw.mp4'},
#  'tkcwbxfroj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jbcnsmlysc.mp4'},
#  'ckpqmqcbms.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'icbzbcwlgf.mp4'},
#  'eazuxemota.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'dbixwxtuxs.mp4'},
#  'rkaxetzemd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'tmgxdytvqm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gztffgsxpt.mp4'},
#  'fxwptihnhr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ddfrexfnhg.mp4'},
#  'quygtqxadv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'cmpkopoabr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vqrsnqwezt.mp4'},
#  'wiqmlyydvl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zdnepyqjiy.mp4'},
#  'xhyjcncbcl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'xgqfinxjgw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'rtuaxyuvqs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'lfsykmsrtl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ihszkmcwvw.mp4'},
#  'znreasaemn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'byzhqvspaz.mp4'},
#  'gjxznmarpw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'nlgccbseha.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ybmpcnodrg.mp4'},
#  'lfqywknpmp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'ggwmjfhixc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ddfrexfnhg.mp4'},
#  'txgnvdjpfl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'yywcdbcdhp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'mlmndeebak.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'ruufnypjin.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ymyjtjywus.mp4'},
#  'lfnuajhyxy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'txfozivwlq.mp4'},
#  'pasgsxejek.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'nhohwyteco.mp4'},
#  'lobucnofjd.mp4': {'label': 'REAL', 'split': 'train'},
#  'wgdqfuadec.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pxwsxsqrxo.mp4'},
#  'xjnptropld.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtwpwdqmxz.mp4'},
#  'sbgqqmotju.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lobucnofjd.mp4'},
#  'puvvywduwt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pxwsxsqrxo.mp4'},
#  'jakjfxcjqx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'soellqnrep.mp4'},
#  'lfjwiittlk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wfmgruqquc.mp4'},
#  'uaqvffouxp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vqrsnqwezt.mp4'},
#  'yicnyhsjfa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'ufizpokygp.mp4': {'label': 'REAL', 'split': 'train'},
#  'ybmpcnodrg.mp4': {'label': 'REAL', 'split': 'train'},
#  'kocjkqdqej.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'swxoosqtkl.mp4'},
#  'ucdxdikiee.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ybmpcnodrg.mp4'},
#  'lepqvhstws.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'fhhgvvydre.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vtlbiwkann.mp4'},
#  'lqbqkjlzma.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'rottyedvaw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lxeqbyddvt.mp4'},
#  'lmrgdusvgw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sytddqezij.mp4'},
#  'rohuegtohf.mp4': {'label': 'REAL', 'split': 'train'},
#  'zqrzqekofe.mp4': {'label': 'REAL', 'split': 'train'},
#  'qkgicklwyn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ocsqqqduxx.mp4'},
#  'mxzosxshju.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ccevbixrwu.mp4'},
#  'ysmngwveyb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'iasfjbowcb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gwzttezkpv.mp4'},
#  'jmszrburbe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xeyzkwymwu.mp4'},
#  'joghmjwscd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wfmgruqquc.mp4'},
#  'ljnwojwbdg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'rxfbkqeydi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'xdjoajcvgw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'swxoosqtkl.mp4'},
#  'dwyaezgzaa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'neuptrhfdr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'awsceniain.mp4'},
#  'djxogftlxw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qzdirjlxbw.mp4'},
#  'ldloctgunu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'azaahiwadu.mp4'},
#  'partcfzlbj.mp4': {'label': 'REAL', 'split': 'train'},
#  'xqeuvgclvw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kffwdagndv.mp4'},
#  'zdnepyqjiy.mp4': {'label': 'REAL', 'split': 'train'},
#  'eqkodjrjyz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kffwdagndv.mp4'},
#  'ubasafrfsx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xrtmepdfyh.mp4'},
#  'gztffgsxpt.mp4': {'label': 'REAL', 'split': 'train'},
#  'xrtmepdfyh.mp4': {'label': 'REAL', 'split': 'train'},
#  'cjrzklaqjt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'xrtmepdfyh.mp4'},
#  'ymyjtjywus.mp4': {'label': 'REAL', 'split': 'train'},
#  'agzpasxmwv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'mnfumgnkml.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'trhuvltfko.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjikbuyuri.mp4'},
#  'mpjfwilxvf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'qplyzcfavt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'ihwgpktjiq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'iqsceqxotz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'icbzbcwlgf.mp4'},
#  'jzmqcigydt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ddfrexfnhg.mp4'},
#  'fnejwhwdee.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'baphsbkpbz.mp4'},
#  'qiklmoeita.mp4': {'label': 'REAL', 'split': 'train'},
#  'cgyficbwoe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'baphsbkpbz.mp4'},
#  'hqpntlbcte.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pxwsxsqrxo.mp4'},
#  'yryxkrwwql.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'jtwpwdqmxz.mp4': {'label': 'REAL', 'split': 'train'},
#  'suunedqyxl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'nhohwyteco.mp4'},
#  'ouwmdrevsh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tvffpggbrc.mp4'},
#  'ckokvqjebx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lobucnofjd.mp4'},
#  'ccdxkfjwdc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'nhohwyteco.mp4'},
#  'pjqqnbiiwv.mp4': {'label': 'REAL', 'split': 'train'},
#  'cfiwjsjltu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ufizpokygp.mp4'},
#  'fggnisskhq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'zekmffwenp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ytowqhkwnk.mp4'},
#  'cfjfplnbrd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hbrgvmrtnn.mp4'},
#  'vwyyxvqkmj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'paorozwtbf.mp4'},
#  'aqwfpoewqb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'awsceniain.mp4'},
#  'gqonceccpe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'ueyqiwnaka.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gwzttezkpv.mp4'},
#  'byzhqvspaz.mp4': {'label': 'REAL', 'split': 'train'},
#  'cnmdwvuecr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'dbixwxtuxs.mp4'},
#  'tjyuudtkme.mp4': {'label': 'REAL', 'split': 'train'},
#  'dymnwzerlb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rohuegtohf.mp4'},
#  'ljieiulczn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jrtgsrmvfu.mp4'},
#  'uijodhxavs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hbrgvmrtnn.mp4'},
#  'hdvazdbvbo.mp4': {'label': 'REAL', 'split': 'train'},
#  'wvhqimwfqm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'kkmugypzhc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vtlbiwkann.mp4'},
#  'wocgulikze.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yhvkmwazup.mp4'},
#  'lxcaipnidg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'bblditzyqm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjikbuyuri.mp4'},
#  'keyiratboy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kdhfvtnpik.mp4'},
#  'xyoqviargc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fafelguets.mp4'},
#  'czlfmczgfs.mp4': {'label': 'REAL', 'split': 'train'},
#  'excmyfrwzp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'sqbuqpxvtt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ufizpokygp.mp4'},
#  'xhfqsughap.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'byzhqvspaz.mp4'},
#  'afolgdwiix.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'yylmbyolqw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cmyvjmgldk.mp4'},
#  'odidbykbar.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'czlfmczgfs.mp4'},
#  'qboupinbkg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'yhvkmwazup.mp4': {'label': 'REAL', 'split': 'train'},
#  'azaahiwadu.mp4': {'label': 'REAL', 'split': 'train'},
#  'hwaslzerct.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kffwdagndv.mp4'},
#  'ycybtwdpej.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lxeqbyddvt.mp4'},
#  'cjorckqkcn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stdavraahk.mp4'},
#  'gakehrooju.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'mazmrfplfz.mp4'},
#  'uzyfjvbstv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gwzttezkpv.mp4'},
#  'ovsjtbttiq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtwpwdqmxz.mp4'},
#  'nhnhwalplb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjikbuyuri.mp4'},
#  'uwfryvyjko.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'kaklqxzcgt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'icbzbcwlgf.mp4'},
#  'wphztpbiqb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'urdegesals.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bogcoldwxa.mp4'},
#  'fzxsggojyo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qiklmoeita.mp4'},
#  'zglkqavueb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'baphsbkpbz.mp4'},
#  'ptlzpuawoo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pbtbftzpia.mp4'},
#  'zlqgtpkchx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djvbsnsiah.mp4'},
#  'vogutjrcxk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wauoeybril.mp4'},
#  'pinreruizk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'czlfmczgfs.mp4'},
#  'shopbbapgj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'paorozwtbf.mp4'},
#  'wfmgruqquc.mp4': {'label': 'REAL', 'split': 'train'},
#  'ctchthbojs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ocsqqqduxx.mp4'},
#  'idtjidropp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ocsqqqduxx.mp4'},
#  'yrbouocjws.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lauifordgs.mp4'},
#  'wjszamwliv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'drnyxcdxmj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lauifordgs.mp4'},
#  'ztmcvkpxyt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cmyvjmgldk.mp4'},
#  'nacldwtuwp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ufizpokygp.mp4'},
#  'annrepersn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'soellqnrep.mp4'},
#  'rhnlbwsyyz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'ikchunmihb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'swxoosqtkl.mp4'},
#  'fotvxamhxh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vtlbiwkann.mp4'},
#  'rmendzfbmz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kffwdagndv.mp4'},
#  'srkrptntea.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cshhakbofs.mp4'},
#  'egamepwdao.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'stwaypekwh.mp4'},
#  'ytrmknbqpl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'hbqewgmkjj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'byzhqvspaz.mp4'},
#  'sgdnbofecu.mp4': {'label': 'REAL', 'split': 'train'},
#  'pfrhiwfnia.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'dosvlktrae.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'partcfzlbj.mp4'},
#  'edvtyrosef.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ihszkmcwvw.mp4'},
#  'rgyidsgwgv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zqrzqekofe.mp4'},
#  'baeoscgqoe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hdvazdbvbo.mp4'},
#  'ftpppcihhj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vqrsnqwezt.mp4'},
#  'kdswzohjqj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vtlbiwkann.mp4'},
#  'jbcnsmlysc.mp4': {'label': 'REAL', 'split': 'train'},
#  'mnftwkbozo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'txfozivwlq.mp4'},
#  'yznmncewlc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ovozllyabv.mp4'},
#  'pfymqrhdqc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bpkpvrqduq.mp4'},
#  'axihbxiqnf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ybmpcnodrg.mp4'},
#  'fahnvsfiwj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ytowqhkwnk.mp4'},
#  'ajmrksuirh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yghxoihrle.mp4'},
#  'chhdhwehot.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtkyoulizr.mp4'},
#  'ehtdvrunlh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'awsceniain.mp4'},
#  'jlzelzmyin.mp4': {'label': 'REAL', 'split': 'train'},
#  'tpragfcvet.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jtwpwdqmxz.mp4'},
#  'nmrdabsqem.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sgdnbofecu.mp4'},
#  'mtiebggcla.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wauoeybril.mp4'},
#  'bogcoldwxa.mp4': {'label': 'REAL', 'split': 'train'},
#  'arpkmdcyta.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kffwdagndv.mp4'},
#  'hgfpjkaots.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cmyvjmgldk.mp4'},
#  'agklhwhjog.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'azaahiwadu.mp4'},
#  'vamickgkfv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'pbtbftzpia.mp4'},
#  'mhjmklcowm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vtlbiwkann.mp4'},
#  'bsalymlxbf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sytddqezij.mp4'},
#  'pmnsqtpgry.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjikbuyuri.mp4'},
#  'ixollenxsr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'txfozivwlq.mp4'},
#  'tvowfywxab.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'anjzzdyhno.mp4'},
#  'lpfmqnxogg.mp4': {'label': 'REAL', 'split': 'train'},
#  'dnrqehggwv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qivnumuetu.mp4'},
#  'encvnokybd.mp4': {'label': 'REAL', 'split': 'train'},
#  'hsjukoflzf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lpfmqnxogg.mp4'},
#  'oejfypsbfh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wedyarmcvw.mp4'},
#  'xyockehads.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kfhkmcvwvd.mp4'},
#  'lvgxlibzrg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'luubupzupe.mp4'},
#  'vbatwpbewy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bufrlvvuuu.mp4'},
#  'qkvybvlifk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'lqtudpjxii.mp4': {'label': 'REAL', 'split': 'train'},
#  'escfavemij.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oqwmglahkz.mp4'},
#  'mzflznofvm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'piwtkahted.mp4': {'label': 'REAL', 'split': 'train'},
#  'obisomyeum.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'luubupzupe.mp4'},
#  'bmkimqkzlh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oqwmglahkz.mp4'},
#  'akyjotmrcu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'qlnfexfowr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ynmluajwre.mp4'},
#  'cnguoshwca.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'guemdthavy.mp4'},
#  'wkgnxvohlt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kfhkmcvwvd.mp4'},
#  'nptmqvfuhz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'qboxvhjwkv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hohrvrekpk.mp4'},
#  'tbcynlkyog.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'udvjwmiwlr.mp4'},
#  'rfbwukxpye.mp4': {'label': 'REAL', 'split': 'train'},
#  'wrmuazxvgr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'dkfyvfjcpr.mp4'},
#  'dlebjfujap.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ztxdkcoxvx.mp4'},
#  'raxupverqg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'xrkdooflmj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hjykhqbhtu.mp4'},
#  'gqiwjxefzm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'trtxfafvta.mp4'},
#  'kvbqyqaqtp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'lfoubkkevo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'uqajkglnmm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ztxdkcoxvx.mp4'},
#  'wiqhrbsfoj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'slvcfpalev.mp4'},
#  'vwjefjjqrr.mp4': {'label': 'REAL', 'split': 'train'},
#  'enzlliylet.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'scbuwbnphb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'uuwidltakm.mp4'},
#  'vpgjaoyvir.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'rayhrvqorn.mp4': {'label': 'REAL', 'split': 'train'},
#  'gswgzcqiav.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cvtwlzgzne.mp4'},
#  'cuewtjauyi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iverjmtcbg.mp4'},
#  'uhbxhharht.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'mfcvohnhjt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yehyyjdfte.mp4'},
#  'kpatdgjera.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qaydrxmkyy.mp4'},
#  'pdywmdvvjy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'fyjgbylvlv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sluwywdyip.mp4'},
#  'nuyjmlcfse.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iverjmtcbg.mp4'},
#  'amptorfnua.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'owysamavpo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qaydrxmkyy.mp4'},
#  'toxhdspkmy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'xgxjqxxjsf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'guemdthavy.mp4': {'label': 'REAL', 'split': 'train'},
#  'ynmluajwre.mp4': {'label': 'REAL', 'split': 'train'},
#  'mkibxglzfg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'myjhgnezbc.mp4'},
#  'ajtbogddxv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lagaytbhyh.mp4'},
#  'kgcofaixqq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'khfdxotgoo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'eqjkjfdbch.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'spccmwkksz.mp4'},
#  'wjzjsnjtra.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bkbokyebco.mp4'},
#  'ojravfhiwk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qivnumuetu.mp4'},
#  'ssjpogjprj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rfbwukxpye.mp4'},
#  'ridcuyswqu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iverjmtcbg.mp4'},
#  'qwmuepplrx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjgkzwbfmz.mp4'},
#  'hrizczebyb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jjzpwcociv.mp4'},
#  'ubtikiqoeg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qaydrxmkyy.mp4'},
#  'sqrjoqavds.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'bkcqlavtab.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qtlgvftgpt.mp4'},
#  'wfxsepsnxb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jjzpwcociv.mp4'},
#  'cyxzkgsafw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'phfljuoghg.mp4'},
#  'kjnabqlvsj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fwisndrpzm.mp4'},
#  'tepxybfdas.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lqtudpjxii.mp4'},
#  'ifdrempraq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fglfkwlujv.mp4'},
#  'weqontqqhu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'oqwxsbecil.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sndxykdojj.mp4'},
#  'vsunyloqes.mp4': {'label': 'REAL', 'split': 'train'},
#  'immfucqwhc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djlkkqmjkk.mp4'},
#  'jabfulxofx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cvtwlzgzne.mp4'},
#  'bkbokyebco.mp4': {'label': 'REAL', 'split': 'train'},
#  'sndxykdojj.mp4': {'label': 'REAL', 'split': 'train'},
#  'ulfppedvdb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'guemdthavy.mp4'},
#  'bngpjglyqu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rvcalvhoxm.mp4'},
#  'iogpvrelcc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'ofsxivhhcf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zmsfyoxdou.mp4'},
#  'cvmmtklgst.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'aquooykzmc.mp4'},
#  'zkcchostsq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sndxykdojj.mp4'},
#  'iewggzdtmd.mp4': {'label': 'REAL', 'split': 'train'},
#  'jhibrhprsb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'xcnxdhjznx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'leuejftlvj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zjbwxmmrgk.mp4'},
#  'lbqskvhlch.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wjrepvzlsv.mp4'},
#  'efakoetljk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bkbokyebco.mp4'},
#  'lmdllckith.mp4': {'label': 'REAL', 'split': 'train'},
#  'snsrdzneby.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'kangomlkoy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tdtgsaspxk.mp4'},
#  'fjbfbanlyx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'cbdquwkipe.mp4': {'label': 'REAL', 'split': 'train'},
#  'ibgocbdxva.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fglfkwlujv.mp4'},
#  'luubupzupe.mp4': {'label': 'REAL', 'split': 'train'},
#  'xretarybyh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'xubgdudrva.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'xticvyqqjn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kmakhupeac.mp4'},
#  'mgmtbzdkgz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vwjefjjqrr.mp4'},
#  'mpnxaoahcx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vwjefjjqrr.mp4'},
#  'xywwihzkwb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjgkzwbfmz.mp4'},
#  'vieltxisfw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'piwtkahted.mp4'},
#  'wedyarmcvw.mp4': {'label': 'REAL', 'split': 'train'},
#  'sluwywdyip.mp4': {'label': 'REAL', 'split': 'train'},
#  'mcbxztarfp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qivnumuetu.mp4'},
#  'seohpnkydn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hohrvrekpk.mp4'},
#  'zqcrjtrjqc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ohnocvcnov.mp4'},
#  'lryvorptpd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'tjjbchgfgp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vcrmlccwlo.mp4'},
#  'otnvpvoulf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'okgrsopppw.mp4'},
#  'mewbjpaoke.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'udvjwmiwlr.mp4'},
#  'dxwizawmim.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qohtjkzity.mp4'},
#  'fsowcwypwz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vdtmlbzhwi.mp4'},
#  'kpemftnnoj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bkbokyebco.mp4'},
#  'sfkihngpxa.mp4': {'label': 'FAKE',
#   'split': 'train',
# ...
#  'faszsqdqgn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'vegxooikmg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'opsswckvib.mp4'},
#  'gaitsfuizp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'luubupzupe.mp4'},
#  'obidvhxtjn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kmakhupeac.mp4'},
#  'yehyyjdfte.mp4': {'label': 'REAL', 'split': 'train'},
#  'cdfvyezjis.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'xzavftnhdl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'gyjdebcqrc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'svmgbkjvhz.mp4'},
#  'mxsdxajbkn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ekxsduhvwh.mp4'},
#  'zmkpjobtvj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'guemdthavy.mp4'},
#  'snkpjieurz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jjzpwcociv.mp4'},
#  'wsyrpvtfne.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'jcfisfexkt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ynmluajwre.mp4'},
#  'fkqzkrmfto.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hjykhqbhtu.mp4'},
#  'uonuagldyy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lmdllckith.mp4'},
#  'mshfuaygyq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sjgkzwbfmz.mp4'},
#  'vzblrxdmxw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lagaytbhyh.mp4'},
#  'snfqbkihqn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'auwljofebi.mp4'},
#  'eltdfmwgji.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bufrlvvuuu.mp4'},
#  'nrxxnkagdt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bufrlvvuuu.mp4'},
#  'ddcymnyysf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'piwtkahted.mp4'},
#  'torbdovazx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ftxavczbvi.mp4'},
#  'xlzraxvakv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'guemdthavy.mp4'},
#  'zjrshbpdik.mp4': {'label': 'REAL', 'split': 'train'},
#  'qtvhpmoukj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sluwywdyip.mp4'},
#  'smthduyjzz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ztxdkcoxvx.mp4'},
#  'amooumaljz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'adsxwxeibr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'okgrsopppw.mp4'},
#  'hohrvrekpk.mp4': {'label': 'REAL', 'split': 'train'},
#  'ybquxguikt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djlkkqmjkk.mp4'},
#  'ruinmlnbze.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iverjmtcbg.mp4'},
#  'vbxorsxlpg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'sndxykdojj.mp4'},
#  'jejzjwuumk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djlkkqmjkk.mp4'},
#  'rxqvqczepk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'zhqknikezo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'itiptpqxpj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'ztxdkcoxvx.mp4': {'label': 'REAL', 'split': 'train'},
#  'acwegmlcgs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vcrmlccwlo.mp4'},
#  'trtxfafvta.mp4': {'label': 'REAL', 'split': 'train'},
#  'tlzukjppsl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kikfjtdgui.mp4'},
#  'jfrcjjfmqo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bkbokyebco.mp4'},
#  'hnhafxatut.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'etrdptdued.mp4'},
#  'pyddtnougq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zjbwxmmrgk.mp4'},
#  'xkiacmotuy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zjbwxmmrgk.mp4'},
#  'kzqqgctnoy.mp4': {'label': 'REAL', 'split': 'train'},
#  'vgglcdhnoe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hlsubhyoea.mp4'},
#  'oxxkuzvaql.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lqtudpjxii.mp4'},
#  'joouypmnuc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zjbwxmmrgk.mp4'},
#  'rfxogycbbi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yehyyjdfte.mp4'},
#  'mwxaqiiqzo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qaydrxmkyy.mp4'},
#  'duywhnombt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bkbokyebco.mp4'},
#  'kikfjtdgui.mp4': {'label': 'REAL', 'split': 'train'},
#  'rvcalvhoxm.mp4': {'label': 'REAL', 'split': 'train'},
#  'bnbuqimfbn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fglfkwlujv.mp4'},
#  'itwegcsfqa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rvcalvhoxm.mp4'},
#  'fwisndrpzm.mp4': {'label': 'REAL', 'split': 'train'},
#  'jvebpyiget.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yehyyjdfte.mp4'},
#  'nzxdgjqehb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ohnocvcnov.mp4'},
#  'jxebflghvt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'piwtkahted.mp4'},
#  'wjoxvojixy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'myjhgnezbc.mp4'},
#  'rdpuptnhrw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'nbhrkijthy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ekxsduhvwh.mp4'},
#  'cxigoqsdoo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qaydrxmkyy.mp4'},
#  'wzihfsuhni.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'auwljofebi.mp4'},
#  'clekngdqxa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qaydrxmkyy.mp4'},
#  'pxrxonthng.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hjykhqbhtu.mp4'},
#  'jukyfuxrka.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'etrdptdued.mp4'},
#  'tcxbfjtdkp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zmsfyoxdou.mp4'},
#  'azobkfldrm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djlkkqmjkk.mp4'},
#  'gomqkftobw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hohrvrekpk.mp4'},
#  'vmnqltuzmx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zmsfyoxdou.mp4'},
#  'ticpxguaeh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ftxavczbvi.mp4'},
#  'klhrwllfsy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'debaivdfyo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gxxlbjuyza.mp4'},
#  'qtftvismyz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'pmuqfywvhy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'tdtgsaspxk.mp4'},
#  'vyhhcubgrb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'udvjwmiwlr.mp4'},
#  'usjekoukzs.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ibvyapyort.mp4'},
#  'ywzkumpcjp.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'optyshszya.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'dtjamuiyiu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'gpolwqideg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'udvjwmiwlr.mp4'},
#  'flhdsqdkib.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'hcrqxnvfyt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'slvcfpalev.mp4'},
#  'vrywrqixcf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'ytpiyuxhsl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rayhrvqorn.mp4'},
#  'isxekfofqe.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'umesravcvu.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kikfjtdgui.mp4'},
#  'fepjgkpkva.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'qmajtoiqoj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ynmluajwre.mp4'},
#  'fhecllzeps.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gxxlbjuyza.mp4'},
#  'ggueyqbwdc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'fjzxygdweh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'opsswckvib.mp4'},
#  'suuvjyupkt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'wjrepvzlsv.mp4'},
#  'kmakhupeac.mp4': {'label': 'REAL', 'split': 'train'},
#  'yeeodzzoxf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'amsrzsvcij.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ftxavczbvi.mp4'},
#  'mvsasyujaa.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jjzpwcociv.mp4'},
#  'exapoobbmo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fglfkwlujv.mp4'},
#  'abwlafapkf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yzkzawtzge.mp4'},
#  'fjdvhqckev.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'aquooykzmc.mp4'},
#  'ecudvgsqtg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'spccmwkksz.mp4'},
#  'dlknkizxrw.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rvcalvhoxm.mp4'},
#  'klmihaypzb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hlsubhyoea.mp4'},
#  'rmeevdmpkq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'upttkhclrb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zjbwxmmrgk.mp4'},
#  'pgkzwuslmz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'udvjwmiwlr.mp4'},
#  'godpfnlizl.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'fhafkpfjwi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kfhkmcvwvd.mp4'},
#  'oavhkxwsrw.mp4': {'label': 'REAL', 'split': 'train'},
#  'ncbempbsch.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fwisndrpzm.mp4'},
#  'jecnyqdnit.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zjbwxmmrgk.mp4'},
#  'vewpuspywj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'nxdilovogq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'opsswckvib.mp4'},
#  'bvaajzstgj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'aquooykzmc.mp4'},
#  'ncgenygrai.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'vzsthtxqgc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iewggzdtmd.mp4'},
#  'uroeempcme.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'opsswckvib.mp4'},
#  'ohnocvcnov.mp4': {'label': 'REAL', 'split': 'train'},
#  'lxdkaxsbra.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'vxhdfsvihq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ibvyapyort.mp4'},
#  'engswoxwys.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ekxsduhvwh.mp4'},
#  'tqyveduvez.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'zpgqqjrtko.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hlsubhyoea.mp4'},
#  'gsjvxclchn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vwjefjjqrr.mp4'},
#  'qwgmdbnovi.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'uuwidltakm.mp4'},
#  'xqtyfrcnww.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'hhpmuiybqn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rayhrvqorn.mp4'},
#  'rxfqtredtd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'opsswckvib.mp4'},
#  'zxuomjbsrf.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kzqqgctnoy.mp4'},
#  'zvajhudwuo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qohtjkzity.mp4'},
#  'qonorwhmkk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qivnumuetu.mp4'},
#  'fgwxkmbrfn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'pmfieukvwd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'lqtudpjxii.mp4'},
#  'goaguxqpdo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kmakhupeac.mp4'},
#  'jvuvxjexte.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jihpgmechw.mp4'},
#  'dkfyvfjcpr.mp4': {'label': 'REAL', 'split': 'train'},
#  'awtnxljuij.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'phfljuoghg.mp4'},
#  'sgcmgytgzn.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'dedqiwxjck.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fwisndrpzm.mp4'},
#  'mvpwumlwfc.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ptfpegxozl.mp4'},
#  'rrmbizcdwv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cbdquwkipe.mp4'},
#  'dylfraworx.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iverjmtcbg.mp4'},
#  'cyokqrzbol.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vsunyloqes.mp4'},
#  'pfpxrcbrmj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'yzkzawtzge.mp4'},
#  'exotjouiuv.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'iverjmtcbg.mp4'},
#  'mlpfcinibo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bkbokyebco.mp4'},
#  'veizpmvwsd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'luubupzupe.mp4'},
#  'phfljuoghg.mp4': {'label': 'REAL', 'split': 'train'},
#  'qcciietoau.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'gxxlbjuyza.mp4'},
#  'ohmfgfvfxj.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'eulslskxei.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'hjykhqbhtu.mp4': {'label': 'REAL', 'split': 'train'},
#  'qieejdykzq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'luubupzupe.mp4'},
#  'qohtjkzity.mp4': {'label': 'REAL', 'split': 'train'},
#  'zjbwxmmrgk.mp4': {'label': 'REAL', 'split': 'train'},
#  'gitzqrhmqk.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'vdtmlbzhwi.mp4'},
#  'fpzpgbugxm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'hohrvrekpk.mp4'},
#  'ustezmxibd.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'myjhgnezbc.mp4'},
#  'qaydrxmkyy.mp4': {'label': 'REAL', 'split': 'train'},
#  'qtlgvftgpt.mp4': {'label': 'REAL', 'split': 'train'},
#  'udvjwmiwlr.mp4': {'label': 'REAL', 'split': 'train'},
#  'ijwmhwupga.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'jjzpwcociv.mp4'},
#  'hawifsawjr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kfhkmcvwvd.mp4'},
#  'xhjihkhtsr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'brxswajyjy.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'phfljuoghg.mp4'},
#  'crmwccddrb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'zkejuxqzpj.mp4'},
#  'jauolugbsh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'oavhkxwsrw.mp4'},
#  'iverjmtcbg.mp4': {'label': 'REAL', 'split': 'train'},
#  'bazehalfin.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kypqqvwvvn.mp4'},
#  'ufyrmbxahb.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bufrlvvuuu.mp4'},
#  'fsvnhagxec.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'djlkkqmjkk.mp4'},
#  'ipqistxtpz.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'auwljofebi.mp4'},
#  'xcrpoppwhm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'fwisndrpzm.mp4'},
#  'svmgbkjvhz.mp4': {'label': 'REAL', 'split': 'train'},
#  'yzhndfopvt.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'trtxfafvta.mp4'},
#  'pjjroahzsq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'udvjwmiwlr.mp4'},
#  'gyccrjplmo.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'bsjucwhlrj.mp4'},
#  'kgqkeovzny.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'kzqqgctnoy.mp4'},
#  'psunkvudmg.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'luubupzupe.mp4'},
#  'qgyftraasm.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rvcalvhoxm.mp4'},
#  'igbyejqxve.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'rayhrvqorn.mp4'},
#  'klncwqllnq.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ynmluajwre.mp4'},
#  'wbhusfdkwh.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'ztxdkcoxvx.mp4'},
#  'gofybzkrli.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'cvtwlzgzne.mp4'},
#  'clrxigzbqr.mp4': {'label': 'FAKE',
#   'split': 'train',
#   'original': 'qohtjkzity.mp4'},
#  ...}

# %% [markdown]
# In this notebook, we'll be using the output from the Mask R-CNN instead of the raw data itself. A challenge is that because of the masking, all of the images are different sizes. To assess feasibility, we need to see what the distribution of those
# sizes is like. From there we can configure a standard size to resize all of them to, with padding.

# %%
data_root = os.path.join("..", "..", "masked_frames")
data_originals = os.path.join(data_root, "originals")

real_train = os.path.join(data_originals, "real_train")
fake_train = os.path.join(data_originals, "fake_train")
real_val = os.path.join(data_originals, "real_val")
fake_val = os.path.join(data_originals, "fake_val")
real_test = os.path.join(data_originals, "real_test")
fake_test = os.path.join(data_originals, "fake_test")

# %%
# Go through all of the folders in each and quantify their sizes

def compute_frame_sizes(real_dir, fake_dir):
    heights = []
    widths = []
    for dir in os.listdir(real_dir):
        for frame in os.listdir(os.path.join(real_dir, dir)):
            img = cv2.imread(os.path.join(real_dir, dir, frame))
            heights.append(img.shape[0])
            widths.append(img.shape[1])
    for dir in os.listdir(fake_dir):
        for frame in os.listdir(os.path.join(fake_dir, dir)):
            img = cv2.imread(os.path.join(fake_dir, dir, frame))
            heights.append(img.shape[0])
            widths.append(img.shape[1])
    
    return heights, widths

# %%
heights, widths = compute_frame_sizes(real_train, fake_train)

# %%
# NOTE: Typically we give image dimensions as width x height like 1920x1080, but cv2 imports the dimensions as
# height x width so 1080x1920
print("Training Set Stats:")
train_pd = pd.DataFrame({'Heights': heights, 'Widths': widths})
print(train_pd.describe())
# Out:
# Training Set Stats:
#            Heights       Widths
# count  9006.000000  9006.000000
# mean    965.184099   602.677437
# std     133.848509   228.361786
# min     294.000000   165.000000
# 25%     921.000000   397.000000
# 50%     988.000000   642.000000
# 75%    1037.000000   757.000000
# max    1685.000000  1590.000000

# %%
heights_v, widths_v = compute_frame_sizes(real_val, fake_val)

# %%
print("Validation Set Stats:")
val_pd = pd.DataFrame({'Heights': heights_v, 'Widths': widths_v})
print(val_pd.describe())
# Out:
# Validation Set Stats:
#            Heights       Widths
# count  1500.000000  1500.000000
# mean    948.962000   556.397333
# std     154.168429   222.555416
# min     637.000000   168.000000
# 25%     902.000000   371.250000
# 50%     978.000000   608.000000
# 75%    1025.000000   708.000000
# max    1623.000000  1086.000000

# %%
heights_t, widths_t = compute_frame_sizes(real_test, fake_test)

# %%
print("Test Set Stats:")
test_pd = pd.DataFrame({'Heights': heights_t, 'Widths': widths_t})
print(test_pd.describe())
# Out:
# Test Set Stats:
#            Heights       Widths
# count  3003.000000  3003.000000
# mean    962.570763   602.338661
# std     126.916398   231.539521
# min     306.000000   166.000000
# 25%     926.000000   405.000000
# 50%     990.000000   645.000000
# 75%    1042.000000   760.000000
# max    1238.000000  1401.000000

# %% [markdown]
# From these stats, it seems that most of the images are laid out in portrait orientation with a longer height. This makes sense since we used Mask R-CNN on people who tend to be taller than wider in frame. In order to stack for batching, we need all of these images to have the same dimensions. Thus we can use isotropic resizing with the images to fix them to the median dimensions of the training set. The isotropic resize function will scale based based on the max sidelength, so we will
# pass the median height there. Width should already be lower in most cases. Then, we will using padding to make the image a square so that everything's a uniform size.

# %%
rescale_transform = Compose([
            IsotropicResize(max_side=988, interpolation_down=cv2.INTER_AREA, interpolation_up=cv2.INTER_CUBIC),
            PadIfNeeded(min_width=988, border_mode=cv2.BORDER_CONSTANT),
        ])

# %% [markdown]
# NOTE: The following cell is for resizing the image and storing in a directory. Only run if those files need to be changed.

# %%
# # Purge the rescaled folder each time
# data_rescaled = os.path.join(data_root, 'rescaled')
# if os.path.isdir(data_rescaled):
#     shutil.rmtree(data_rescaled)

# # Now create the folder and setup its subdirectories
# os.mkdir(data_rescaled)
# rescale_train = os.path.join(data_rescaled, 'train')
# rescale_val = os.path.join(data_rescaled, 'val')
# rescale_test = os.path.join(data_rescaled, 'test')

# subdirs = {
#     rescale_train: [real_train, fake_train],
#     rescale_val: [real_val, fake_val],
#     rescale_test: [real_test, fake_test],
# }

# for subdir in subdirs.keys():
#     os.mkdir(subdir)


# # Each subdirectory corresponds to a group - train, validation, or test. Each of those has two original folders (fake
# # and real) to absorb. We will go through the 2 original folders for each subdirectory and store all the images
# # together for ease.
# for subdir in subdirs.keys():  # train, val, test
#     for label_group in subdirs[subdir]:  # real, fake
#         for img_group in os.listdir(label_group):  # video id
#             for img in os.listdir(os.path.join(label_group, img_group)):
#                 rescaled = rescale_transform(image=cv2.imread(os.path.join(label_group, img_group, img)))['image']
                
#                 frame_num = img.split('.')[0][5:]  # Cut by extension to get frame# and then skip 'frame'
#                 new_name = img_group + '_' + frame_num + '.jpg'
#                 cv2.imwrite(os.path.join(subdir, new_name), rescaled)

# %% [markdown]
# ## Dataset Object

# %%
class FrameDataset(Dataset):

    def __init__(self, metadata: dict, img_dir: str, transform=None) -> None:
        super().__init__()
        self.img_dir = img_dir

        # Go through the names of all the images in the directory. Compile a set of just the video names
        filenames = os.listdir(img_dir)

        vid_names = set()
        for filename in filenames:
            vid_names.add(filename.split('_')[0])

        # Now for each video name, pull up all the frames and add the images
        self.id = []
        self.frames = []
        self.labels = []
        for vid_name in vid_names:
            for i in range(0, 300, 30):
                self.id.append(vid_name)
                self.labels.append(0 if metadata[vid_name]['label']=='REAL' else 1)

                frame_name = f'{vid_name}_{i}.jpg'
                self.frames.append(frame_name)

    def __len__(self) -> int:
        return len(self.labels)
    
    def __getitem__(self, index):
        # Most of the images are in landscape orientation where cv2 will read them height, width, channels. A few
        # are in portrait mode so they are read in width, height, channels. We need to use swap axes to fix these
        img = cv2.imread(os.path.join(self.img_dir, self.frames[index]))
        if img.shape[0] > img.shape[1]:
            # print('trigger')
            img = img.swapaxes(0, 1)

        return self.id[index], to_tensor(cv2.resize(img, (0,0), fx=0.1, fy=0.1, interpolation=cv2.INTER_AREA)), self.labels[index]

# %%
cv2.imread(os.path.join(fake_test, 'amsrzsvcij', 'frame1.jpg')).shape
# Out:
# (748, 354, 3)
